# %%
import os
import cv2
import numpy as np
from collections import defaultdict

import scikitplot
import seaborn as sns
from matplotlib import pyplot

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import TimeDistributed, LSTM, Bidirectional
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# surprise has 249 number of images
# fear has 75 number of images
# sadness has 84 number of images
# happy has 207 number of images
# anger has 135 number of images

# %% [markdown]
# `sadness` and `fear` has very low number of images as compared to other classes

# %%
TOP_EMOTIONS = ["happy", "surprise", "anger", "sadness", "fear"]

# %% [markdown]
# ### Data Preprocessing
#
# I first make the data compatible for neural nets

# %%
INPUT_PATH = "../input/ck48-5-emotions/CK+48/"

data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# data

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])

def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]

def img2array(x,path):
    arr = np.empty(shape=(3,48,48))
    for i,f in enumerate(x):
        img = cv2.imread(path+f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())

    data[emotion] = dict((k, img2array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# %%
for k,v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# surprise has 83 samples
# fear has 25 samples
# sadness has 28 samples
# happy has 69 samples
# anger has 45 samples

# %%
surprise = np.stack(data["surprise"].values(), axis=0)
surprise = surprise.reshape(*surprise.shape,1)

happy = np.stack(data["happy"].values(), axis=0)
happy = happy.reshape(*happy.shape,1)

anger = np.stack(data["anger"].values(), axis=0)
anger = anger.reshape(*anger.shape,1)

sadness = np.stack(data["sadness"].values(), axis=0)
sadness = sadness.reshape(*sadness.shape,1)

fear = np.stack(data["fear"].values(), axis=0)
fear = fear.reshape(*fear.shape,1)

X = np.concatenate((surprise, happy, anger, sadness, fear))
y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))
y = np_utils.to_categorical(y)

X.shape, y.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# ((250, 3, 48, 48, 1), (250, 5))

# %%
label_emotion_mapper = {0:"surprise", 1:"happy", 2:"anger", 3:"sadness", 4:"fear"}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, stratify=y, shuffle=True, random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((175, 3, 48, 48, 1), (75, 3, 48, 48, 1))

# %%
np.random.seed(42)
surprise_idx = np.random.choice(np.where(y_train[:, 0]==1)[0], size=1)
happy_idx = np.random.choice(np.where(y_train[:, 1]==1)[0], size=1)
anger_idx = np.random.choice(np.where(y_train[:, 2]==1)[0], size=1)
sad_idx = np.random.choice(np.where(y_train[:, 3]==1)[0], size=1)
fear_idx = np.random.choice(np.where(y_train[:, 4]==1)[0], size=1)

fig = pyplot.figure(1, (6,13))

i = 0
for name, idx in zip(label_emotion_mapper.values(), [surprise_idx, happy_idx, anger_idx, sad_idx, fear_idx]):
    for j in range(3):
        i += 1
        ax = pyplot.subplot(5,3,i)
        sample_img = X_train[idx][0,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(name)

# %%
# data normalization
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
def build_dcnn(input_shape, show_arch=True):
    """
    This is a Deep Convolutional Neural Network (DCNN). For generalization purpose I used dropouts in regular intervals.
    I used `ELU` as the activation because it avoids dying relu problem but also performed well as compared to LeakyRelu
    atleast in this case. `he_normal` kernel initializer is used as it suits ELU. BatchNormalization is also used for better
    results.
    """
    net = Sequential(name='DCNN')
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            input_shape=input_shape,
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
    net.add(Dropout(0.25, name='dropout_1'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
    net.add(Dropout(0.25, name='dropout_2'))

    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_5'
        )
    )
    net.add(BatchNormalization(name='batchnorm_7'))
    net.add(
        Conv2D(
            filters=256,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_6'
        )
    )
    net.add(BatchNormalization(name='batchnorm_8'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
    net.add(Dropout(0.3, name='dropout_3'))

    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_7'
        )
    )
    net.add(BatchNormalization(name='batchnorm_9'))
    net.add(
        Conv2D(
            filters=512,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_8'
        )
    )
    net.add(BatchNormalization(name='batchnorm_10'))
    
    net.add(Dropout(0.3, name='dropout_4'))
    
    net.add(GlobalMaxPool2D(name="globalmax2d"))
    
    if show_arch:
        net.summary()
    
    return net

# %%
def memory_model(input_shape, num_class, show_arch=True):
    dcnn = build_dcnn(input_shape[1:], show_arch=False)
    
    model = Sequential(name="convolutional_Bidrectional_LSTM")

    model.add(
        TimeDistributed(
            dcnn,
            input_shape=input_shape,
            name="time_distributed",
        )
    )
    
    model.add(Bidirectional(LSTM(128, return_sequences=True, name="bidirect_lstm_1")))
    model.add(Dropout(.35, name="dropout_1"))
    model.add(Bidirectional(LSTM(64, return_sequences=False, name="bidirect_lstm_2")))
    model.add(Dropout(.45, name="dropout_2"))

    model.add(
        Dense(
            128,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    model.add(BatchNormalization(name='batchnorm_1'))
    model.add(Dropout(.7, name="dropout_3"))

    model.add(
        Dense(
            num_class,
            activation='softmax',
            name='out_layer'
        )
    )
    
    if show_arch:
        model.summary()
    
    return model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
#     early_stopping,
    lr_scheduler,
]

batch_size = 32
epochs = 100

# %%
INPUT_SHAPE = (3,48, 48, 1)
optim = optimizers.Nadam(0.001)

model = memory_model(INPUT_SHAPE, num_class=5)
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)
# Out:
# Model: "convolutional_Bidrectional_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 3, 512)            4691904
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 3, 256)            656384
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 5)                 645
# =================================================================
# Total params: 5,530,309
# Trainable params: 5,526,213
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_valid, y_valid),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train on 175 samples, validate on 75 samples
# Epoch 1/100
# 175/175 [==============================] - 10s 55ms/sample - loss: 3.0743 - accuracy: 0.2400 - val_loss: 1.6473 - val_accuracy: 0.1067
# Epoch 2/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.6097 - accuracy: 0.2343 - val_loss: 1.6646 - val_accuracy: 0.0800
# Epoch 3/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.1998 - accuracy: 0.2400 - val_loss: 1.7258 - val_accuracy: 0.1067
# Epoch 4/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 3.0942 - accuracy: 0.2000 - val_loss: 1.6432 - val_accuracy: 0.1067
# Epoch 5/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.7221 - accuracy: 0.1657 - val_loss: 1.5883 - val_accuracy: 0.1200
# Epoch 6/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.5886 - accuracy: 0.2571 - val_loss: 1.5288 - val_accuracy: 0.2933
# Epoch 7/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.4113 - accuracy: 0.2514 - val_loss: 1.5976 - val_accuracy: 0.2800
# Epoch 8/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.3065 - accuracy: 0.3143 - val_loss: 1.5035 - val_accuracy: 0.3067
# Epoch 9/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 2.2436 - accuracy: 0.4171 - val_loss: 1.3735 - val_accuracy: 0.4133
# Epoch 10/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.5562 - accuracy: 0.5257 - val_loss: 1.2810 - val_accuracy: 0.5200
# Epoch 11/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.4751 - accuracy: 0.5029 - val_loss: 1.3249 - val_accuracy: 0.4533
# Epoch 12/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2757 - accuracy: 0.5600 - val_loss: 0.9889 - val_accuracy: 0.6667
# Epoch 13/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.2287 - accuracy: 0.6000 - val_loss: 1.1688 - val_accuracy: 0.5200
# Epoch 14/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9749 - accuracy: 0.6857 - val_loss: 0.8997 - val_accuracy: 0.6933
# Epoch 15/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0550 - accuracy: 0.6400 - val_loss: 0.8883 - val_accuracy: 0.6933
# Epoch 16/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0487 - accuracy: 0.6514 - val_loss: 0.8187 - val_accuracy: 0.7200
# Epoch 17/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.1454 - accuracy: 0.6743 - val_loss: 1.1705 - val_accuracy: 0.4533
# Epoch 18/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 1.0552 - accuracy: 0.6514 - val_loss: 1.1461 - val_accuracy: 0.5600
# Epoch 19/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9624 - accuracy: 0.6857 - val_loss: 0.6827 - val_accuracy: 0.7333
# Epoch 20/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9573 - accuracy: 0.7029 - val_loss: 0.7247 - val_accuracy: 0.7067
# Epoch 21/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8992 - accuracy: 0.6971 - val_loss: 0.8763 - val_accuracy: 0.6667
# Epoch 22/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9335 - accuracy: 0.6743 - val_loss: 0.7184 - val_accuracy: 0.7200
# Epoch 23/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7295 - accuracy: 0.7771 - val_loss: 0.7476 - val_accuracy: 0.6933
# Epoch 24/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.9510 - accuracy: 0.6800 - val_loss: 0.6783 - val_accuracy: 0.7333
# Epoch 25/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7073 - accuracy: 0.7314 - val_loss: 0.5314 - val_accuracy: 0.7733
# Epoch 26/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7091 - accuracy: 0.7829 - val_loss: 0.5910 - val_accuracy: 0.7733
# Epoch 27/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.8353 - accuracy: 0.6971 - val_loss: 0.5981 - val_accuracy: 0.7867
# Epoch 28/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7522 - accuracy: 0.7429 - val_loss: 0.5949 - val_accuracy: 0.8133
# Epoch 29/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7922 - accuracy: 0.7829 - val_loss: 0.8440 - val_accuracy: 0.7333
# Epoch 30/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6975 - accuracy: 0.7829 - val_loss: 0.6315 - val_accuracy: 0.7467
# Epoch 31/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5749 - accuracy: 0.8000 - val_loss: 0.3848 - val_accuracy: 0.8533
# Epoch 32/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5442 - accuracy: 0.7714 - val_loss: 0.3794 - val_accuracy: 0.8267
# Epoch 33/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.7260 - accuracy: 0.7886 - val_loss: 0.4290 - val_accuracy: 0.8000
# Epoch 34/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5783 - accuracy: 0.7714 - val_loss: 0.4367 - val_accuracy: 0.8267
# Epoch 35/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5759 - accuracy: 0.8114 - val_loss: 0.4254 - val_accuracy: 0.8267
# Epoch 36/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4644 - accuracy: 0.8286 - val_loss: 1.0605 - val_accuracy: 0.6667
# Epoch 37/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5847 - accuracy: 0.7943 - val_loss: 0.7911 - val_accuracy: 0.6800
# Epoch 38/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.6862 - accuracy: 0.7625
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6602 - accuracy: 0.7714 - val_loss: 0.7624 - val_accuracy: 0.7200
# Epoch 39/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.6086 - accuracy: 0.7829 - val_loss: 0.8835 - val_accuracy: 0.7200
# Epoch 40/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4639 - accuracy: 0.8229 - val_loss: 0.6246 - val_accuracy: 0.8133
# Epoch 41/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3984 - accuracy: 0.8343 - val_loss: 0.4796 - val_accuracy: 0.8267
# Epoch 42/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.4912 - accuracy: 0.8286 - val_loss: 0.4414 - val_accuracy: 0.8267
# Epoch 43/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3578 - accuracy: 0.8629 - val_loss: 0.4498 - val_accuracy: 0.8133
# Epoch 44/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2652 - accuracy: 0.9143 - val_loss: 0.3933 - val_accuracy: 0.8667
# Epoch 45/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3374 - accuracy: 0.8743 - val_loss: 0.4811 - val_accuracy: 0.8000
# Epoch 46/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3703 - accuracy: 0.8686 - val_loss: 0.5730 - val_accuracy: 0.8533
# Epoch 47/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.5211 - accuracy: 0.8514 - val_loss: 0.7283 - val_accuracy: 0.7867
# Epoch 48/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3029 - accuracy: 0.8800 - val_loss: 0.3741 - val_accuracy: 0.8533
# Epoch 49/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3038 - accuracy: 0.8743 - val_loss: 0.8290 - val_accuracy: 0.8000
# Epoch 50/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.3187 - accuracy: 0.8686 - val_loss: 0.3202 - val_accuracy: 0.8800
# Epoch 51/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2363 - accuracy: 0.8914 - val_loss: 0.5665 - val_accuracy: 0.8400
# Epoch 52/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2810 - accuracy: 0.8743 - val_loss: 0.3812 - val_accuracy: 0.8533
# Epoch 53/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2713 - accuracy: 0.9029 - val_loss: 0.3431 - val_accuracy: 0.8800
# Epoch 54/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2020 - accuracy: 0.9143 - val_loss: 0.4616 - val_accuracy: 0.8533
# Epoch 55/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2392 - accuracy: 0.9143 - val_loss: 0.5077 - val_accuracy: 0.8533
# Epoch 56/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2080 - accuracy: 0.9314 - val_loss: 0.4600 - val_accuracy: 0.8533
# Epoch 57/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.1805 - accuracy: 0.9500
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2329 - accuracy: 0.9429 - val_loss: 0.4240 - val_accuracy: 0.8667
# Epoch 58/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1791 - accuracy: 0.9371 - val_loss: 0.5129 - val_accuracy: 0.8933
# Epoch 59/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.2052 - accuracy: 0.9371 - val_loss: 0.5369 - val_accuracy: 0.8533
# Epoch 60/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1957 - accuracy: 0.9257 - val_loss: 0.3925 - val_accuracy: 0.8667
# Epoch 61/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0936 - accuracy: 0.9714 - val_loss: 0.3703 - val_accuracy: 0.8933
# Epoch 62/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1101 - accuracy: 0.9714 - val_loss: 0.3315 - val_accuracy: 0.9067
# Epoch 63/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1562 - accuracy: 0.9371 - val_loss: 0.3738 - val_accuracy: 0.8800
# Epoch 64/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1497 - accuracy: 0.9371 - val_loss: 0.4523 - val_accuracy: 0.8533
# Epoch 65/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1287 - accuracy: 0.9543 - val_loss: 0.4976 - val_accuracy: 0.8800
# Epoch 66/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1128 - accuracy: 0.9714 - val_loss: 0.5633 - val_accuracy: 0.8800
# Epoch 67/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1501 - accuracy: 0.9486 - val_loss: 0.3304 - val_accuracy: 0.8933
# Epoch 68/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1292 - accuracy: 0.9714 - val_loss: 0.5538 - val_accuracy: 0.8400
# Epoch 69/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.1326 - accuracy: 0.9563
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1257 - accuracy: 0.9600 - val_loss: 0.4654 - val_accuracy: 0.8933
# Epoch 70/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1477 - accuracy: 0.9600 - val_loss: 0.4261 - val_accuracy: 0.8933
# Epoch 71/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1807 - accuracy: 0.9657 - val_loss: 0.7173 - val_accuracy: 0.8267
# Epoch 72/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1416 - accuracy: 0.9600 - val_loss: 0.5045 - val_accuracy: 0.8667
# Epoch 73/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0890 - accuracy: 0.9714 - val_loss: 0.3331 - val_accuracy: 0.9067
# Epoch 74/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1326 - accuracy: 0.9657 - val_loss: 0.5451 - val_accuracy: 0.8533
# Epoch 75/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0939 - accuracy: 0.9771 - val_loss: 0.3394 - val_accuracy: 0.8667
# Epoch 76/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.0587 - accuracy: 0.9812
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0882 - accuracy: 0.9771 - val_loss: 0.4294 - val_accuracy: 0.8667
# Epoch 77/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1131 - accuracy: 0.9486 - val_loss: 0.3426 - val_accuracy: 0.9200
# Epoch 78/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1028 - accuracy: 0.9657 - val_loss: 0.3911 - val_accuracy: 0.8933
# Epoch 79/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0788 - accuracy: 0.9829 - val_loss: 0.4014 - val_accuracy: 0.8800
# Epoch 80/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1044 - accuracy: 0.9543 - val_loss: 0.4463 - val_accuracy: 0.8267
# Epoch 81/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0937 - accuracy: 0.9600 - val_loss: 0.4320 - val_accuracy: 0.8667
# Epoch 82/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0845 - accuracy: 0.9714 - val_loss: 0.4119 - val_accuracy: 0.8533
# Epoch 83/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0842 - accuracy: 0.9771 - val_loss: 0.4532 - val_accuracy: 0.8800
# Epoch 84/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.0548 - accuracy: 0.9875
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0527 - accuracy: 0.9886 - val_loss: 0.4319 - val_accuracy: 0.8533
# Epoch 85/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1611 - accuracy: 0.9600 - val_loss: 0.5409 - val_accuracy: 0.8667
# Epoch 86/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0460 - accuracy: 0.9943 - val_loss: 0.5607 - val_accuracy: 0.8667
# Epoch 87/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0776 - accuracy: 0.9886 - val_loss: 0.5746 - val_accuracy: 0.8800
# Epoch 88/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0560 - accuracy: 0.9943 - val_loss: 0.4674 - val_accuracy: 0.8933
# Epoch 89/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0786 - accuracy: 0.9714 - val_loss: 0.4176 - val_accuracy: 0.8933
# Epoch 90/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0433 - accuracy: 0.9886 - val_loss: 0.4040 - val_accuracy: 0.8933
# Epoch 91/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.0440 - accuracy: 0.9937
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0563 - accuracy: 0.9886 - val_loss: 0.5569 - val_accuracy: 0.8667
# Epoch 92/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0509 - accuracy: 0.9829 - val_loss: 0.4793 - val_accuracy: 0.8800
# Epoch 93/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8800
# Epoch 94/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0844 - accuracy: 0.9714 - val_loss: 0.4915 - val_accuracy: 0.8800
# Epoch 95/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0374 - accuracy: 0.9943 - val_loss: 0.5034 - val_accuracy: 0.8667
# Epoch 96/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0702 - accuracy: 0.9886 - val_loss: 0.4676 - val_accuracy: 0.9067
# Epoch 97/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.1224 - accuracy: 0.9771 - val_loss: 0.3548 - val_accuracy: 0.9067
# Epoch 98/100
# 160/175 [==========================>...] - ETA: 0s - loss: 0.0380 - accuracy: 0.9937
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0355 - accuracy: 0.9943 - val_loss: 0.3434 - val_accuracy: 0.9200
# Epoch 99/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0751 - accuracy: 0.9829 - val_loss: 0.3608 - val_accuracy: 0.9200
# Epoch 100/100
# 175/175 [==============================] - 0s 2ms/sample - loss: 0.0717 - accuracy: 0.9771 - val_loss: 0.3835 - val_accuracy: 0.9200

# %%
sns.set()
fig = pyplot.figure(0, (6, 5))
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.xlabel("No of Epoch",  fontdict = font2)
pyplot.ylabel("Accuracy",  fontdict = font2)
pyplot.title('Model Accuracy',  fontdict = font1)
pyplot.savefig('model_accuracy.png')
# pyplot.tight_layout()

# %%
fig = pyplot.figure(0, (6, 5))
# ax = pyplot.subplot(1, 1, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.xlabel("No of Epoch",  fontdict = font2)
pyplot.ylabel("Accuracy",  fontdict = font2)
pyplot.title('Model Loss',  fontdict = font1)
# pyplot.tight_layout()

pyplot.savefig('model_loss.png')
pyplot.show()

# %% [markdown]
# `The fluctuations in the epoch metrics is due to the fact that we have very low data for such a complex task.`

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
yhat_valid = model.predict_classes(X_valid)
cm =confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid )
sns.set(rc= {"figure.figsize": (5,4)})
ax = sns.heatmap(cm, annot=True, cmap='Blues')
ax.set_title('Confusion matrix using CNN And Bi LSTM ', fontsize = 10, fontweight=500);
ax.set_xlabel('\nPredicted Values',fontweight=700)
ax.set_ylabel('Actual Values ',fontweight=700);


ax.xaxis.set_ticklabels(["Happy", "Surprise", "Anger", "Sadness", "Fear"], fontsize=9);
ax.yaxis.set_ticklabels(["Happy", "Surprise", "Anger", "Sadness", "Fear"],  fontsize=9);

pyplot.savefig("confusion_matrix.png")

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid, target_names=["happy", "surprise", "anger", "sadness", "fear"]))
# Out:
# total wrong validation predictions: 6
#
#
#               precision    recall  f1-score   support
#
#        happy       1.00      1.00      1.00        25
#     surprise       0.95      1.00      0.98        21
#        anger       0.92      0.85      0.88        13
#      sadness       0.64      0.88      0.74         8
#         fear       1.00      0.62      0.77         8
#
#     accuracy                           0.92        75
#    macro avg       0.90      0.87      0.87        75
# weighted avg       0.93      0.92      0.92        75

# %%
### ROC Curve
# roc curve for classes
from sklearn import metrics
from sklearn.metrics import roc_curve,auc
from itertools import cycle
from matplotlib import pyplot as plt
fpr = {}
tpr = {}
thresh ={}
auc = {}
y_prob_pred_cnb =  model.predict_proba(X_valid)

y_test =  np.argmax(y_valid,axis=1)


n_class = 5
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = metrics.roc_curve(y_test, y_prob_pred_cnb[:,1], pos_label=i)
    auc[i] = metrics.roc_auc_score(y_test,y_prob_pred_cnb, multi_class='ovr',average='weighted')
    
# plotting    
font = {'family' : '',
        'weight' : 'bold',
        'size'   : 8.5}

plt.rc('font', **font)
plt.figure(figsize=(6,6))
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='happy vs Rest, auc = '+str(auc[0])[:4])
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='surprise vs Rest, auc = '+str(auc[1])[:4])
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='anger vs Rest, auc = '+str(auc[2])[:4])
plt.plot(fpr[3], tpr[3], linestyle='--',color='red', label='sadness vs Rest, auc = '+str(auc[3])[:4])
plt.plot(fpr[4], tpr[4], linestyle='--',color='pink', label='fear vs Rest, auc = '+str(auc[4])[:4])

plt.title('Multiclass ROC curve',fontsize=12,fontweight='bold',)
plt.xlabel('False Positive Rate',fontsize=12,fontweight='bold')
plt.ylabel('True Positive Rate',fontsize=12,fontweight='bold')
plt.legend(loc='best')
plt.savefig('Multiclass_ROC.png',dpi=300);

# %% [markdown]
# `If we have more data to train then we will get better and more generalized model.`

# %%
np.random.seed(0)
indices = np.random.choice(range(X_valid.shape[0]), size=15, replace=False)

fig = pyplot.figure(1, (9,30))

i = 0
for idx in indices:
    true_emotion = label_emotion_mapper[np.argmax(y_valid[idx])]
    pred_emotion = label_emotion_mapper[model.predict_classes(np.expand_dims(X_valid[idx], axis=0))[0]]
    
    for j in range(3):
        i += 1
        ax = pyplot.subplot(15,3,i)
        sample_img = X_valid[idx,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:{true_emotion}, p:{pred_emotion}")
