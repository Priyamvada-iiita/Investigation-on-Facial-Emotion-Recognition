# %%
import os
import cv2
import numpy as np
from collections import defaultdict

import scikitplot
import seaborn as sns
from matplotlib import pyplot

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, GlobalMaxPool2D
from tensorflow.keras.layers import TimeDistributed, LSTM, Bidirectional
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau

from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
# Out:
# Using TensorFlow backend.

# %%
INPUT_PATH = "../input/ckplus/CK+48/"

for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# surprise has 249 number of images
# fear has 75 number of images
# sadness has 84 number of images
# disgust has 177 number of images
# contempt has 54 number of images
# happy has 207 number of images
# anger has 135 number of images

# %% [markdown]
# `sadness` and `fear` has very low number of images as compared to other classes

# %%
TOP_EMOTIONS = ["happy", "surprise", "anger", "sadness", "fear"]

# %% [markdown]
# ### Data Preprocessing
#
# I first make the data compatible for neural nets

# %%
INPUT_PATH = "../input/ckplus/CK+48/"

data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# data

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])

def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]

def img2array(x,path):
    arr = np.empty(shape=(3,48,48))
    for i,f in enumerate(x):
        img = cv2.imread(path+f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())

    data[emotion] = dict((k, img2array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# %%
for k,v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# surprise has 83 samples
# fear has 25 samples
# sadness has 28 samples
# happy has 69 samples
# anger has 45 samples

# %%
surprise = np.stack(data["surprise"].values(), axis=0)
surprise = surprise.reshape(*surprise.shape,1)

happy = np.stack(data["happy"].values(), axis=0)
happy = happy.reshape(*happy.shape,1)

anger = np.stack(data["anger"].values(), axis=0)
anger = anger.reshape(*anger.shape,1)

sadness = np.stack(data["sadness"].values(), axis=0)
sadness = sadness.reshape(*sadness.shape,1)

fear = np.stack(data["fear"].values(), axis=0)
fear = fear.reshape(*fear.shape,1)

X = np.concatenate((surprise, happy, anger, sadness, fear))
y = np.concatenate((np.array([0]*83), np.array([1]*69), np.array([2]*45), np.array([3]*28), np.array([4]*25)))
y = np_utils.to_categorical(y)

X.shape, y.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3254: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# ((250, 3, 48, 48, 1), (250, 5))

# %%
label_emotion_mapper = {0:"surprise", 1:"happy", 2:"anger", 3:"sadness", 4:"fear"}

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.7, stratify=y, shuffle=True, random_state=42)
X_train.shape, X_valid.shape
# Out:
# ((175, 3, 48, 48, 1), (75, 3, 48, 48, 1))

# %%
np.random.seed(42)
surprise_idx = np.random.choice(np.where(y_train[:, 0]==1)[0], size=1)
happy_idx = np.random.choice(np.where(y_train[:, 1]==1)[0], size=1)
anger_idx = np.random.choice(np.where(y_train[:, 2]==1)[0], size=1)
sad_idx = np.random.choice(np.where(y_train[:, 3]==1)[0], size=1)
fear_idx = np.random.choice(np.where(y_train[:, 4]==1)[0], size=1)

fig = pyplot.figure(1, (6,13))

i = 0
for name, idx in zip(label_emotion_mapper.values(), [surprise_idx, happy_idx, anger_idx, sad_idx, fear_idx]):
    for j in range(3):
        i += 1
        ax = pyplot.subplot(5,3,i)
        sample_img = X_train[idx][0,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(name)

# %%
# data normalization
X_train = X_train / 255.
X_valid = X_valid / 255.

# %%
def build_dcnn(input_shape, show_arch=True):
    """
    This is a Deep Convolutional Neural Network (DCNN). For generalization purpose I used dropouts in regular intervals.
    I used `ELU` as the activation because it avoids dying relu problem but also performed well as compared to LeakyRelu
    atleast in this case. `he_normal` kernel initializer is used as it suits ELU. BatchNormalization is also used for better
    results.
    """
    net = Sequential(name='DCNN')
    net.add(
        Conv2D(
            filters=32,
            kernel_size=(3,3),
            input_shape=input_shape,
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_1'
        )
    )
    net.add(BatchNormalization(name='batchnorm_3'))
    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_2'
        )
    )
    net.add(BatchNormalization(name='batchnorm_4'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_1'))
#     net.add(Dropout(0.25, name='dropout_1'))

    net.add(
        Conv2D(
            filters=64,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_3'
        )
    )
    net.add(BatchNormalization(name='batchnorm_5'))
    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_4'
        )
    )
    net.add(BatchNormalization(name='batchnorm_6'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_2'))
#     net.add(Dropout(0.25, name='dropout_2'))

    net.add(
        Conv2D(
            filters=128,
            kernel_size=(3,3),
            activation='elu',
            padding='same',
            kernel_initializer='he_normal',
            name='conv2d_5'
        )
    )
#     net.add(BatchNormalization(name='batchnorm_7'))
#     net.add(
#         Conv2D(
#             filters=256,
#             kernel_size=(3,3),
#             activation='elu',
#             padding='same',
#             kernel_initializer='he_normal',
#             name='conv2d_6'
#         )
#     )
#     net.add(BatchNormalization(name='batchnorm_8'))
    
    net.add(MaxPooling2D(pool_size=(2,2), name='maxpool2d_3'))
#     net.add(Dropout(0.3, name='dropout_3'))

#     net.add(
#         Conv2D(
#             filters=512,
#             kernel_size=(3,3),
#             activation='elu',
#             padding='same',
#             kernel_initializer='he_normal',
#             name='conv2d_7'
#         )
#     )
#     net.add(BatchNormalization(name='batchnorm_9'))
#     net.add(
#         Conv2D(
#             filters=512,
#             kernel_size=(3,3),
#             activation='elu',
#             padding='same',
#             kernel_initializer='he_normal',
#             name='conv2d_8'
#         )
#     )
#     net.add(BatchNormalization(name='batchnorm_10'))
    
#     net.add(Dropout(0.3, name='dropout_4'))
    
    net.add(GlobalMaxPool2D(name="globalmax2d"))
    
    if show_arch:
        net.summary()
    
    return net

# %%
def memory_model(input_shape, num_class, show_arch=True):
    dcnn = build_dcnn(input_shape[1:], show_arch=False)
    
    model = Sequential(name="convolutional_Bidrectional_LSTM")

    model.add(
        TimeDistributed(
            dcnn,
            input_shape=input_shape,
            name="time_distributed",
        )
    )
    
    model.add((LSTM(128, return_sequences=True, name="lstm_1")))
#     model.add(Dropout(.35, name="dropout_1"))
    model.add((LSTM(64, return_sequences=False, name="lstm_2")))
#     model.add(Dropout(.45, name="dropout_2"))

    model.add(
        Dense(
            200,
            activation='elu',
            kernel_initializer='he_normal',
            name='dense_1'
        )
    )
    model.add(BatchNormalization(name='batchnorm_1'))
    model.add(Dropout(.6, name="dropout_3"))

    model.add(
        Dense(
            num_class,
            activation='softmax',
            name='out_layer'
        )
    )
    
    if show_arch:
        model.summary()
    
    return model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
#     early_stopping,
    lr_scheduler,
]

batch_size = 32
epochs = 100

# %%
INPUT_SHAPE = (3,48, 48, 1)
optim = optimizers.Nadam(0.001)

model = memory_model(INPUT_SHAPE, num_class=5)
model.compile(
        loss='categorical_crossentropy',
        optimizer=optim,
        metrics=['accuracy']
)
# Out:
# Model: "convolutional_Bidrectional_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 3, 128)            278336
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 3, 128)            131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               13000
# _________________________________________________________________
# batchnorm_1 (BatchNormalizat (None, 200)               800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 200)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 5)                 1005
# =================================================================
# Total params: 474,133
# Trainable params: 473,157
# Non-trainable params: 976
# _________________________________________________________________

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_valid, y_valid),
    batch_size=batch_size,
    epochs=50,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Train on 175 samples, validate on 75 samples
# Epoch 1/50
# 175/175 [==============================] - 6s 37ms/sample - loss: 2.1769 - accuracy: 0.3257 - val_loss: 1.5655 - val_accuracy: 0.3333
# Epoch 2/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 1.4524 - accuracy: 0.5143 - val_loss: 1.5846 - val_accuracy: 0.3467
# Epoch 3/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 1.0253 - accuracy: 0.6743 - val_loss: 1.5782 - val_accuracy: 0.3467
# Epoch 4/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.6590 - accuracy: 0.7371 - val_loss: 1.5874 - val_accuracy: 0.3067
# Epoch 5/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.4021 - accuracy: 0.8571 - val_loss: 1.5625 - val_accuracy: 0.3867
# Epoch 6/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.2307 - accuracy: 0.9314 - val_loss: 1.5735 - val_accuracy: 0.2533
# Epoch 7/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.1978 - accuracy: 0.9257 - val_loss: 1.5700 - val_accuracy: 0.1867
# Epoch 8/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0832 - accuracy: 0.9829 - val_loss: 1.5116 - val_accuracy: 0.4933
# Epoch 9/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.1809 - accuracy: 0.9543 - val_loss: 1.5363 - val_accuracy: 0.1733
# Epoch 10/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0994 - accuracy: 0.9714 - val_loss: 1.5394 - val_accuracy: 0.2133
# Epoch 11/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0357 - accuracy: 0.9943 - val_loss: 1.5081 - val_accuracy: 0.2400
# Epoch 12/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0535 - accuracy: 0.9886 - val_loss: 1.4816 - val_accuracy: 0.2667
# Epoch 13/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0221 - accuracy: 0.9943 - val_loss: 1.4250 - val_accuracy: 0.4133
# Epoch 14/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.3927 - val_accuracy: 0.4800
# Epoch 15/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0235 - accuracy: 1.0000 - val_loss: 1.3683 - val_accuracy: 0.5067
# Epoch 16/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0213 - accuracy: 0.9943 - val_loss: 1.3981 - val_accuracy: 0.3733
# Epoch 17/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0700 - accuracy: 0.9886 - val_loss: 1.3517 - val_accuracy: 0.4667
# Epoch 18/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0681 - accuracy: 0.9829 - val_loss: 1.2771 - val_accuracy: 0.6133
# Epoch 19/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0184 - accuracy: 1.0000 - val_loss: 1.2115 - val_accuracy: 0.6933
# Epoch 20/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.2206 - val_accuracy: 0.6133
# Epoch 21/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.1650 - val_accuracy: 0.6667
# Epoch 22/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.1703 - val_accuracy: 0.6667
# Epoch 23/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0142 - accuracy: 0.9943 - val_loss: 1.0634 - val_accuracy: 0.7600
# Epoch 24/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.0204 - val_accuracy: 0.7467
# Epoch 25/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.9722 - val_accuracy: 0.7467
# Epoch 26/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.9942 - val_accuracy: 0.7200
# Epoch 27/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0481 - accuracy: 0.9943 - val_loss: 1.1821 - val_accuracy: 0.6000
# Epoch 28/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.1116 - accuracy: 0.9829 - val_loss: 1.1068 - val_accuracy: 0.5733
# Epoch 29/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0327 - accuracy: 0.9943 - val_loss: 1.7283 - val_accuracy: 0.2933
# Epoch 30/50
# 160/175 [==========================>...] - ETA: 0s - loss: 0.1946 - accuracy: 0.9500
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.1784 - accuracy: 0.9543 - val_loss: 1.4975 - val_accuracy: 0.2667
# Epoch 31/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0357 - accuracy: 0.9886 - val_loss: 1.4259 - val_accuracy: 0.3333
# Epoch 32/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0205 - accuracy: 0.9943 - val_loss: 1.1944 - val_accuracy: 0.4667
# Epoch 33/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0210 - accuracy: 0.9943 - val_loss: 1.0623 - val_accuracy: 0.5600
# Epoch 34/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0115 - accuracy: 0.9943 - val_loss: 1.0315 - val_accuracy: 0.5867
# Epoch 35/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0127 - accuracy: 0.9943 - val_loss: 0.8591 - val_accuracy: 0.7600
# Epoch 36/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.8048 - val_accuracy: 0.7600
# Epoch 37/50
# 160/175 [==========================>...] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.7908 - val_accuracy: 0.7600
# Epoch 38/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.8075 - val_accuracy: 0.7600
# Epoch 39/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.7600
# Epoch 40/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7381 - val_accuracy: 0.7600
# Epoch 41/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7009 - val_accuracy: 0.7867
# Epoch 42/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6744 - val_accuracy: 0.7867
# Epoch 43/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.6646 - val_accuracy: 0.7867
# Epoch 44/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6552 - val_accuracy: 0.7867
# Epoch 45/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6435 - val_accuracy: 0.7867
# Epoch 46/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6350 - val_accuracy: 0.7867
# Epoch 47/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.6234 - val_accuracy: 0.8000
# Epoch 48/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.7867
# Epoch 49/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6026 - val_accuracy: 0.7867
# Epoch 50/50
# 175/175 [==============================] - 0s 1ms/sample - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5894 - val_accuracy: 0.8000

# %%
sns.set()
fig = pyplot.figure(0, (6, 5))
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.xlabel("No of Epoch",  fontdict = font2)
pyplot.ylabel("Accuracy",  fontdict = font2)
pyplot.title('Model Accuracy',  fontdict = font1)
pyplot.savefig('model_accuracy.png')
# pyplot.tight_layout()

# %%
fig = pyplot.figure(0, (6, 5))
# ax = pyplot.subplot(1, 1, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.xlabel("No of Epoch",  fontdict = font2)
pyplot.ylabel("Accuracy",  fontdict = font2)
pyplot.title('Model Loss',  fontdict = font1)
# pyplot.tight_layout()

pyplot.savefig('model_loss.png')
pyplot.show()

# %% [markdown]
# `The fluctuations in the epoch metrics is due to the fact that we have very low data for such a complex task.`

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
yhat_valid = model.predict_classes(X_valid)
cm =confusion_matrix(np.argmax(y_valid, axis=1), yhat_valid )
sns.set(rc= {"figure.figsize": (5,4)})
ax = sns.heatmap(cm, annot=True, cmap='Blues')
ax.set_title('Confusion matrix using CNN And LSTM ', fontsize = 10, fontweight=500);
ax.set_xlabel('\nPredicted Values',fontweight=700)
ax.set_ylabel('Actual Values ',fontweight=700);


ax.xaxis.set_ticklabels(["Happy", "Surprise", "Anger", "Sadness", "Fear"], fontsize=9);
ax.yaxis.set_ticklabels(["Happy", "Surprise", "Anger", "Sadness", "Fear"],  fontsize=9);

pyplot.savefig("confusion_matrix.png")

print(f'total wrong validation predictions: {np.sum(np.argmax(y_valid, axis=1) != yhat_valid)}\n\n')
print(classification_report(np.argmax(y_valid, axis=1), yhat_valid, target_names=["happy", "surprise", "anger", "sadness", "fear"]))
# Out:
# total wrong validation predictions: 15
#
#
#               precision    recall  f1-score   support
#
#        happy       0.96      1.00      0.98        25
#     surprise       0.81      1.00      0.89        21
#        anger       0.62      1.00      0.76        13
#      sadness       0.50      0.12      0.20         8
#         fear       0.00      0.00      0.00         8
#
#     accuracy                           0.80        75
#    macro avg       0.58      0.62      0.57        75
# weighted avg       0.71      0.80      0.73        75
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
### ROC Curve
# roc curve for classes
from sklearn import metrics
from sklearn.metrics import roc_curve,auc
from itertools import cycle
from matplotlib import pyplot as plt
fpr = {}
tpr = {}
thresh ={}
auc = {}
y_prob_pred_cnb =  model.predict_proba(X_valid)

y_test =  np.argmax(y_valid,axis=1)


n_class = 5
for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = metrics.roc_curve(y_test, y_prob_pred_cnb[:,1], pos_label=i)
    auc[i] = metrics.roc_auc_score(y_test,y_prob_pred_cnb, multi_class='ovr',average='weighted')
    
# plotting    
font = {'family' : '',
        'weight' : 'bold',
        'size'   : 8.5}

plt.rc('font', **font)
plt.figure(figsize=(6,6))
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='happy vs Rest, auc = '+str(auc[0])[:4])
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='surprise vs Rest, auc = '+str(auc[1])[:4])
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='anger vs Rest, auc = '+str(auc[2])[:4])
plt.plot(fpr[3], tpr[3], linestyle='--',color='red', label='sadness vs Rest, auc = '+str(auc[3])[:4])
plt.plot(fpr[4], tpr[4], linestyle='--',color='pink', label='fear vs Rest, auc = '+str(auc[4])[:4])

plt.title('Multiclass ROC curve',fontsize=12,fontweight='bold',)
plt.xlabel('False Positive Rate',fontsize=12,fontweight='bold')
plt.ylabel('True Positive Rate',fontsize=12,fontweight='bold')
plt.legend(loc='best')
plt.savefig('Multiclass_ROC.png',dpi=300);
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family [] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# `If we have more data to train then we will get better and more generalized model.`

# %%
np.random.seed(0)
indices = np.random.choice(range(X_valid.shape[0]), size=15, replace=False)

fig = pyplot.figure(1, (9,30))

i = 0
for idx in indices:
    true_emotion = label_emotion_mapper[np.argmax(y_valid[idx])]
    pred_emotion = label_emotion_mapper[model.predict_classes(np.expand_dims(X_valid[idx], axis=0))[0]]
    
    for j in range(3):
        i += 1
        ax = pyplot.subplot(15,3,i)
        sample_img = X_valid[idx,j,:,:,0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:{true_emotion}, p:{pred_emotion}")
